# %% [markdown]
# ## How to generate Random Fake Data using Faker
#
# Faker is a python package that generates fake dataset. Whether we need it to bootstrap our database, create good-looking XML documents, fill-in-your persistence to stress test it, or anonymize data taken from a production service, Faker is used.

# %%
# Create Fake Dummy Data
from faker import Faker
fake = Faker('hi_IN')

# %% [markdown]
# ### Lets create some information for the database

# %%
for _ in range(5):
    print(fake.name())
# Out:
# विजय मजूमदार
# शौर्य हासन
# गावित, निशा
# कुमार, प्रबोध
# कुमार, आद्या

# %% [markdown]
# To create different dates, faker provides different ways to create fake dates and times. In the following code blocks, we will learn 10 different ways to create dummy dates and times data.

# %%
print(fake.month())
print(fake.date_time())
print(fake.year())
print(fake.month_name())
print(fake.date_time_this_year())
print(fake.time())
print(fake.timezone())
print(fake.day_of_week())
print(fake.time_object())
# Out:
# 04
# 1990-08-10 06:30:39
# 1980
# जुलाई
# 2022-01-03 04:58:55
# 12:24:51
# Africa/Maseru
# मंगलवार
# 20:48:17

# %%
# Create a personal profile
print(fake.simple_profile())
# Out:
# {'username': 'dmngl', 'name': 'गणेश दयाल', 'sex': 'F', 'address': '7365 साई डानी\nधर्मापुरी 190932', 'mail': 'vmngl@yahoo.com', 'birthdate': datetime.date(1925, 2, 13)}

# %%
# Create a dataframe using pandas with faker
import pandas as pd
data = [fake.profile() for i in range(10)]
df = pd.DataFrame(data)
fake_bban_list = [fake.bban() for i in range(len(df))]
df['bank_account'] = fake_bban_list
fake_swift_code_list = [fake.swift() for i in range(len(df))]
df['swift_code'] = fake_swift_code_list
df = df[['name', 'address', 'birthdate', 'bank_account', 'swift_code', 'sex', 'company', 'job', 'mail']]
df.head()
# Out:
#           name                          address   birthdate  \
# 0   अखिल पाटिल           381 डार\nचिराला 573042  2001-09-10
# 1  पुष्पा मंडल      8177 शर्मा\nचित्रकूट-900152  2008-07-09
# 2  कैलाश हुसैन          1 महाजन\nचित्तूर-747410  1908-09-12
# 3    अशोक काले  72/162 बालकृष्णन\nधारवाड 601819  1978-02-24
# 4     एषा सिंह      3/4 बक्षी\nबहादुरगंज 428454  1964-08-31
#
#          bank_account   swift_code sex                     company  \
# 0  TDUO97256876651302     XTAXGBUR   F  बालकृष्णन, लाला and महादेव
# 1  COIV60005904193080  VJLHGB0F3FJ   F                    बजाज Inc
# 2  VEJC89431646318560     INZPGBCQ   F                   अली-कुमार
# 3  SRPO76080155330183     ZXWPGBET   F     बादामी, कृष्णा and मंगल
# 4  VFVP68816476752701  CJETGBGTT24   M     गणेश, बादामी and कुण्डा
#
#                                   job                            mail
# 0         Passenger transport manager        raamshrmaaiish@yahoo.com
# 1                          Cabin crew  mohnbaalaasubrmnniym@gmail.com
# 2    Education officer, environmental        gaanguliiessaa@yahoo.com
# 3  Logistics and distribution manager       dddhaalshyaamaa@yahoo.com
# 4                    Doctor, hospital      vissnnukulkrnnii@yahoo.com

# %%
df.head()
# Out:
#                           job                   company          ssn  \
# 0         Scientist, forensic                 जमानत Ltd  186-89-2183
# 1                 Firefighter              ड़ाल and Sons  147-72-1481
# 2  Further education lecturer             गायकवाड-हेगडे  360-52-1226
# 3         Administrator, arts           कृष्णमूर्ति LLC  285-90-3261
# 4  Civil engineer, consulting  दादा, मजूमदार and नूरानी  313-65-5652
#
#                            residence           current_location blood_group  \
# 0      19/748 अब्बासी\nचिपलुन-549722   (74.3039465, -31.751587)         AB-
# 1   1474 अमायरा कुमार\nअमरोहा-160847    (-17.782093, 85.870779)          O-
# 2           10/70 लाल\nफतेहगढ-922985  (28.1301075, -172.430051)         AB+
# 3  643 देन्यल अग्रवाल\nपाकाला-593274   (-13.449506, -81.029400)          A-
# 4    0/3 हासन गणेश\nमोकोकचुंग-338854   (-14.699564, 175.910386)         AB-
#
#                                              website         username  \
# 0  [https://baabuu.biz/, http://www.diikssit-raam...     raaynvikaavi
# 1  [http://jmaant-bsu.info/, https://www.baadaami...          riyaa55
# 2  [http://dossii.com/, https://dhaaliivaal-bkssi...          fbkssii
# 3            [http://www.dve.com/, https://grg.com/]        ayaansh61
# 4      [http://luuthraa.net/, https://caudhrii.org/]  paattilgovindaa
#
#              name sex                                address  \
# 0  राजीव श्रीविमल   F  79/155 फ़ातिमा कुण्डा\nफतेहपुर 642672
# 1      ज़ारा छाबरा   M   92/807 पूर्णिमा सिंह\nअमरावती 145347
# 2  अभिलाषा विकावि   F        54/012 अहलुवालिया\nअलांग 587946
# 3      गौतम कुमार   M      3 गौतम मजूमदार\nचित्रदुर्ग 080297
# 4       आहूजा, ईश   F                69/251 मंडल\nअसम 614890
#
#                         mail   birthdate        bank_account   swift_code
# 0   aarusshusain@hotmail.com  1922-08-27  RCNO77081468046794  LMDGGB4D6AI
# 1  baadaamiirohn@hotmail.com  1915-12-13  XZMU05673233488288  TMRLGBZPMK0
# 2     shyaamaa74@hotmail.com  1925-08-29  PBLJ34156774000225     LOKOGBKJ
# 3   raamllaamukesh@gmail.com  2007-09-02  FSII83672852620598  MBOTGBBXPFO
# 4      sinhsaaii@hotmail.com  1981-07-22  EKHH75067300689113     PUFOGBMM

# %%
df.head()
# Out:
#              name                                address   birthdate  \
# 0  राजीव श्रीविमल  79/155 फ़ातिमा कुण्डा\nफतेहपुर 642672  1922-08-27
# 1      ज़ारा छाबरा   92/807 पूर्णिमा सिंह\nअमरावती 145347  1915-12-13
# 2  अभिलाषा विकावि        54/012 अहलुवालिया\nअलांग 587946  1925-08-29
# 3      गौतम कुमार      3 गौतम मजूमदार\nचित्रदुर्ग 080297  2007-09-02
# 4       आहूजा, ईश                69/251 मंडल\nअसम 614890  1981-07-22
#
#          bank_account   swift_code sex                   company  \
# 0  RCNO77081468046794  LMDGGB4D6AI   F                 जमानत Ltd
# 1  XZMU05673233488288  TMRLGBZPMK0   M              ड़ाल and Sons
# 2  PBLJ34156774000225     LOKOGBKJ   F             गायकवाड-हेगडे
# 3  FSII83672852620598  MBOTGBBXPFO   M           कृष्णमूर्ति LLC
# 4  EKHH75067300689113     PUFOGBMM   F  दादा, मजूमदार and नूरानी
#
#                           job                       mail
# 0         Scientist, forensic   aarusshusain@hotmail.com
# 1                 Firefighter  baadaamiirohn@hotmail.com
# 2  Further education lecturer     shyaamaa74@hotmail.com
# 3         Administrator, arts   raamllaamukesh@gmail.com
# 4  Civil engineer, consulting      sinhsaaii@hotmail.com
